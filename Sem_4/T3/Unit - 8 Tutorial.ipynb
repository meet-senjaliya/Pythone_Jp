# %% [markdown]
# ## Introduction to Django

# %% [markdown]
# ### Check the version
# ```python
# python -m django --version
# ```
# - If Django is not installed; install using following command
# ```
# pip install django
# ```

# %% [markdown]
# ### Create a django project
# ```
# python -m django startproject myproject
# cd myproject
#
# ## Runserver
# python manage.py runserver
# ```
#
# ## Create an app
# ```
# python manage.py startapp demoapp
#
# ```
# -> Register the `demoapp` in settings.py

# %% [markdown]
# ## PRACTICE - Create a project - Amazonwebsite
# ### Also create two apps - cart and products
# #### Run the dev server
