# %% [markdown]
# ## FCSP-2 T-1 Syllabus
# - Unit - 1 Pandas
#     - 13 marks ~ 9 marks online code
# - Unit - 2 - Visualization
#     - 8 marks
# - Unit - 3 - INtro to ML(theory)
#     - 4 marks

# %% [markdown]
# # Pandas -
# - Panel data system used for data manipulation

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create series
# - 1D pandas data structure

# %%
# Using list
a = pd.Series([2,3,4,5])
a
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
# Using tuple
a = pd.Series((20,30,40,50),index=[10,20,30,40])
a
# Out:
# 10    20
# 20    30
# 30    40
# 40    50
# dtype: int64

# %%
# Using dictionary
pd.Series({
    "A":90,
    "B":80,
    "C":100
})
# Out:
# A     90
# B     80
# C    100
# dtype: int64

# %% [markdown]
# ## DataFrame
# - A 2D pandas datastructure

# %%
pd.DataFrame({
    "name":['a','b','c'],
    "marks":[90,100,120]
})
# Out:
#   name  marks
# 0    a     90
# 1    b    100
# 2    c    120

# %%
pd.DataFrame({
    "name":pd.Series(['A',"B"]),
    "marks": pd.Series([80,90])
})
# Out:
#   name  marks
# 0    A     80
# 1    B     90

# %%
pwd
# Out:
# 'C:\\Users\\LJENG'

# %% [markdown]
# ## Import and Read csv

# %%
df = pd.read_csv("mydata.csv")

# %%
df
# Out:
#   Name  Age City
# 0    a   10  AMD
# 1    b   20  DEL
# 2    c   30  BOM

# %% [markdown]
# ## Exercise -
# - load students csv from Datasets folder in ftp

# %%
pwd

# %%
df = pd.read_csv("students.csv")
df
# Out:
#     StudentID    Name Department   Age  Marks  Attendance       City
# 0           1    Amit         CS  20.0   85.0        92.0  Ahmedabad
# 1           2    Neha         IT  21.0   78.0        88.0      Surat
# 2           3    Ravi         CS  19.0   90.0        95.0  Ahmedabad
# 3           4    Sara         EC  22.0   66.0        70.0   Vadodara
# 4           5    John         IT  20.0  120.0        85.0     Rajkot
# 5           6   Kiran         CS  21.0   81.0        90.0  Ahmedabad
# 6           7    Riya         IT  20.0   76.0         NaN      Surat
# 7           8   Arjun         CS  22.0    NaN        93.0  Ahmedabad
# 8           9   Pooja         EC  19.0   69.0        75.0   Vadodara
# 9          10   Mehul         CS  21.0   92.0        97.0  Ahmedabad
# 10         11   Anita         IT  20.0   74.0        80.0      Surat
# 11         12   Rohan         CS  22.0   84.0        91.0  Ahmedabad
# 12         13   Deepa         EC   NaN   67.0        72.0   Vadodara
# ...

# %% [markdown]
# ## set index and reset index

# %%
df.set_index("StudentID",inplace=True)

# %%
df
# Out:
#              Name Department   Age  Marks  Attendance       City
# StudentID
# 1            Amit         CS  20.0   85.0        92.0  Ahmedabad
# 2            Neha         IT  21.0   78.0        88.0      Surat
# 3            Ravi         CS  19.0   90.0        95.0  Ahmedabad
# 4            Sara         EC  22.0   66.0        70.0   Vadodara
# 5            John         IT  20.0  120.0        85.0     Rajkot
# 6           Kiran         CS  21.0   81.0        90.0  Ahmedabad
# 7            Riya         IT  20.0   76.0         NaN      Surat
# 8           Arjun         CS  22.0    NaN        93.0  Ahmedabad
# 9           Pooja         EC  19.0   69.0        75.0   Vadodara
# 10          Mehul         CS  21.0   92.0        97.0  Ahmedabad
# 11          Anita         IT  20.0   74.0        80.0      Surat
# 12          Rohan         CS  22.0   84.0        91.0  Ahmedabad
# 13          Deepa         EC   NaN   67.0        72.0   Vadodara
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     StudentID    Name Department   Age  Marks  Attendance       City
# 0           1    Amit         CS  20.0   85.0        92.0  Ahmedabad
# 1           2    Neha         IT  21.0   78.0        88.0      Surat
# 2           3    Ravi         CS  19.0   90.0        95.0  Ahmedabad
# 3           4    Sara         EC  22.0   66.0        70.0   Vadodara
# 4           5    John         IT  20.0  120.0        85.0     Rajkot
# 5           6   Kiran         CS  21.0   81.0        90.0  Ahmedabad
# 6           7    Riya         IT  20.0   76.0         NaN      Surat
# 7           8   Arjun         CS  22.0    NaN        93.0  Ahmedabad
# 8           9   Pooja         EC  19.0   69.0        75.0   Vadodara
# 9          10   Mehul         CS  21.0   92.0        97.0  Ahmedabad
# 10         11   Anita         IT  20.0   74.0        80.0      Surat
# 11         12   Rohan         CS  22.0   84.0        91.0  Ahmedabad
# 12         13   Deepa         EC   NaN   67.0        72.0   Vadodara
# ...

# %% [markdown]
# ## DATAFRAME ATTRIBUTES

# %%
print(df.shape)
print(df.ndim)
print(df.size)
print(df.columns)
print(df.index)
print(df.dtypes)
print(df.values)
# Out:
# (22, 7)
# 2
# 154
# Index(['StudentID', 'Name', 'Department', 'Age', 'Marks', 'Attendance',
#        'City'],
#       dtype='object')
# RangeIndex(start=0, stop=22, step=1)
# StudentID       int64
# Name           object
# Department     object
# Age           float64
# Marks         float64
# Attendance    float64
# City           object
# dtype: object
# [[1 'Amit' 'CS' 20.0 85.0 92.0 'Ahmedabad']
#  [2 'Neha' 'IT' 21.0 78.0 88.0 'Surat']
#  [3 'Ravi' 'CS' 19.0 90.0 95.0 'Ahmedabad']
#  [4 'Sara' 'EC' 22.0 66.0 70.0 'Vadodara']
#  [5 'John' 'IT' 20.0 120.0 85.0 'Rajkot']
#  [6 'Kiran' 'CS' 21.0 81.0 90.0 'Ahmedabad']
#  [7 'Riya' 'IT' 20.0 76.0 nan 'Surat']
#  [8 'Arjun' 'CS' 22.0 nan 93.0 'Ahmedabad']
#  [9 'Pooja' 'EC' 19.0 69.0 75.0 'Vadodara']
#  [10 'Mehul' 'CS' 21.0 92.0 97.0 'Ahmedabad']
#  [11 'Anita' 'IT' 20.0 74.0 80.0 'Surat']
#  [12 'Rohan' 'CS' 22.0 84.0 91.0 'Ahmedabad']
#  [13 'Deepa' 'EC' nan 67.0 72.0 'Vadodara']
#  [14 'Sneha' 'IT' 20.0 79.0 86.0 'Surat']
# ...

# %% [markdown]
# ## INDEXING AND SLICING USING LOC AND ILOC

# %% [markdown]
# ### `loc` method
# - it is a label based indexing

# %%
data = {
    "Name": ['A','B','C','D','E','F'],
    "Marks": [88,87,83,79,34,46],
    "Bonus": [5,3,7,4,9,2],
    "City": ['ahmedabad','surat','ahmedabad','ahmedabad','rajkot','surat']
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks  Bonus       City
# 0    A     88      5  ahmedabad
# 1    B     87      3      surat
# 2    C     83      7  ahmedabad
# 3    D     79      4  ahmedabad
# 4    E     34      9     rajkot
# 5    F     46      2      surat

# %%
df.loc[5]
# Out:
# Name         F
# Marks       46
# Bonus        2
# City     surat
# Name: 5, dtype: object

# %%
df.loc[5,"Name"]
# Out:
# 'F'

# %%
df.loc[5,"Name"] = "Z"

# %%
df
# Out:
#   Name  Marks  Bonus       City
# 0    A     88      5  ahmedabad
# 1    B     87      3      surat
# 2    C     83      7  ahmedabad
# 3    D     79      4  ahmedabad
# 4    E     34      9     rajkot
# 5    Z     46      2      surat

# %%
df1 = df[["Name","City","Bonus"]]

# %%
df1
# Out:
#   Name       City  Bonus
# 0    A  ahmedabad      5
# 1    B      surat      3
# 2    C  ahmedabad      7
# 3    D  ahmedabad      4
# 4    E     rajkot      9
# 5    F      surat      2

# %% [markdown]
# ## Slicing

# %%
df
# Out:
#   Name  Marks  Bonus       City
# 0    A     88      5  ahmedabad
# 1    B     87      3      surat
# 2    C     83      7  ahmedabad
# 3    D     79      4  ahmedabad
# 4    E     34      9     rajkot
# 5    Z     46      2      surat

# %%
df.loc[0:2,['Name', 'Bonus']]
# Out:
#   Name  Bonus
# 0    A      5
# 1    B      3
# 2    C      7

# %% [markdown]
# ## Add column

# %%
df.loc[:,"Total"] = df["Marks"] + df["Bonus"]
df
# Out:
#   Name  Marks  Bonus       City  Total
# 0    A     88      5  ahmedabad     93
# 1    B     87      3      surat     90
# 2    C     83      7  ahmedabad     90
# 3    D     79      4  ahmedabad     83
# 4    E     34      9     rajkot     43
# 5    Z     46      2      surat     48

# %% [markdown]
# ## Add Row

# %%
df.loc[6] = ["M",50,5,'ahmedabad',55]

# %%
df
# Out:
#   Name  Marks  Bonus       City  Total
# 0    A     88      5  ahmedabad     93
# 1    B     87      3      surat     90
# 2    C     83      7  ahmedabad     90
# 3    D     79      4  ahmedabad     83
# 4    E     34      9     rajkot     43
# 5    Z     46      2      surat     48
# 6    M     50      5  ahmedabad     55

# %% [markdown]
# ## `iloc method`
# - index based method

# %%
df.iloc[0]
# Out:
# Name             A
# Marks           88
# Bonus            5
# City     ahmedabad
# Total           93
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#   Name  Marks  Bonus       City  Total
# 0    A     88      5  ahmedabad     93
# 1    B     87      3      surat     90
# 2    C     83      7  ahmedabad     90

# %% [markdown]
# ## Slicing

# %%
df.iloc[0:3,0:2]
# Out:
#   Name  Marks
# 0    A     88
# 1    B     87
# 2    C     83

# %% [markdown]
# ## Viewing data
# ### head()
# - To view first 5 rows

# %%
df.head(3)
# Out:
#   Name  Marks  Bonus       City  Total
# 0    A     88      5  ahmedabad     93
# 1    B     87      3      surat     90
# 2    C     83      7  ahmedabad     90

# %% [markdown]
# ## tail()
# - to view last 5 rows

# %%
df.tail(3)
# Out:
#   Name  Marks  Bonus       City  Total
# 4    E     34      9     rajkot     43
# 5    Z     46      2      surat     48
# 6    M     50      5  ahmedabad     55

# %% [markdown]
# ## sample()
# - to randomly view data

# %%
df.sample(2)
# Out:
#   Name  Marks  Bonus       City  Total
# 2    C     83      7  ahmedabad     90
# 4    E     34      9     rajkot     43

# %% [markdown]
# ## info() inspect method
# - to check the datatypes and memory of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Bonus   7 non-null      int64
#  3   City    7 non-null      object
#  4   Total   7 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 336.0+ bytes

# %% [markdown]
# ## describe method
# - to view statistical summary of the data
#
# **syntax**
#
# ```python
# df.describe(include = ,exclude = , percentiles = )
# ```

# %%
df.describe().round(2)
# Out:
#        Marks  Bonus  Total
# count   7.00   7.00   7.00
# mean   66.71   5.00  71.71
# std    22.58   2.38  22.04
# min    34.00   2.00  43.00
# 25%    48.00   3.50  51.50
# 50%    79.00   5.00  83.00
# 75%    85.00   6.00  90.00
# max    88.00   9.00  93.00

# %%
df.describe(include="all").round(2)
# Out:
#        Name  Marks  Bonus       City  Total
# count     7   7.00   7.00          7   7.00
# unique    7    NaN    NaN          3    NaN
# top       B    NaN    NaN  ahmedabad    NaN
# freq      1    NaN    NaN          4    NaN
# mean    NaN  66.71   5.00        NaN  71.71
# std     NaN  22.58   2.38        NaN  22.04
# min     NaN  34.00   2.00        NaN  43.00
# 25%     NaN  48.00   3.50        NaN  51.50
# 50%     NaN  79.00   5.00        NaN  83.00
# 75%     NaN  85.00   6.00        NaN  90.00
# max     NaN  88.00   9.00        NaN  93.00

# %%
df.describe(exclude="object").round(2)
# Out:
#        Marks  Bonus  Total
# count   7.00   7.00   7.00
# mean   66.71   5.00  71.71
# std    22.58   2.38  22.04
# min    34.00   2.00  43.00
# 25%    48.00   3.50  51.50
# 50%    79.00   5.00  83.00
# 75%    85.00   6.00  90.00
# max    88.00   9.00  93.00

# %%
df.describe(percentiles=[.2,.3,.7,.9]).round(2)
# Out:
#        Marks  Bonus  Total
# count   7.00   7.00   7.00
# mean   66.71   5.00  71.71
# std    22.58   2.38  22.04
# min    34.00   2.00  43.00
# 20%    46.80   3.20  49.40
# 30%    49.20   3.80  53.60
# 50%    79.00   5.00  83.00
# 70%    83.80   5.40  90.00
# 90%    87.40   7.80  91.20
# max    88.00   9.00  93.00

# %% [markdown]
# ## unique and nunique method

# %%
df["City"].unique()
# Out:
# array(['ahmedabad', 'surat', 'rajkot'], dtype=object)

# %%
df["City"].nunique()
# Out:
# 3

# %% [markdown]
# ## value_counts()

# %%
df["City"].value_counts()
# Out:
# ahmedabad    4
# surat        2
# rajkot       1
# Name: City, dtype: int64

# %%
df["City"].value_counts(ascending=True)
# Out:
# rajkot       1
# surat        2
# ahmedabad    4
# Name: City, dtype: int64

# %% [markdown]
# ## Missing data handling
# - Used extensively in Data Science for cleaning data

# %% [markdown]
# ## `isnull()` method
# - It checks the null values in the dataframe

# %%
df.loc[0,"Marks"] = np.nan

# %%
df
# Out:
#   Name  Marks  Bonus       City  Total
# 0    A    NaN      5  ahmedabad     93
# 1    B   87.0      3      surat     90
# 2    C   83.0      7  ahmedabad     90
# 3    D   79.0      4  ahmedabad     83
# 4    E   34.0      9     rajkot     43
# 5    Z   46.0      2      surat     48
# 6    M   50.0      5  ahmedabad     55

# %%
df.isnull()
# Out:
#     Name  Marks  Bonus   City  Total
# 0  False   True  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False
# 5  False  False  False  False  False
# 6  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# Name     0
# Marks    1
# Bonus    0
# City     0
# Total    0
# dtype: int64

# %% [markdown]
# ## fillna method
# - It is used to fill the null values
#
# **syntax**
# ```python
# df.fillna(value)
# ```

# %%
df.fillna(80,inplace=True)

# %%
df
# Out:
#   Name  Marks  Bonus       City  Total
# 0    A   80.0      5  ahmedabad     93
# 1    B   87.0      3      surat     90
# 2    C   83.0      7  ahmedabad     90
# 3    D   79.0      4  ahmedabad     83
# 4    E   34.0      9     rajkot     43
# 5    Z   46.0      2      surat     48
# 6    M   50.0      5  ahmedabad     55

# %% [markdown]
# ## `dropna` method
#
# - It removes rows/columns containing missing values
#
# **syntax**
# ```python
# df.dropna(axis=0,how='any',thresh=,subset=,inplace=False)
# ```

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### load data

# %%
data = {
    "Name": ["A",'B','C','D','E'],
    "Marks": [85,np.nan,78,np.nan,90],
    "Bonus": [5,7,np.nan,6,5],
    "City": ["ahmedabad","surat","rajkot","ahmedabad",None]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
# 1    B    NaN    7.0      surat
# 2    C   78.0    NaN     rajkot
# 3    D    NaN    6.0  ahmedabad
# 4    E   90.0    5.0       None

# %% [markdown]
# ### `axis=0/1`
# - To remove rows or columns containing null values
#     - 0 = rows with null values
#     - 1 = columns with null values

# %%
df.dropna(axis=0)
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad

# %%
df.dropna(axis=1)
# Out:
#   Name
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
df.fillna(100)
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
# 1    B  100.0    7.0      surat
# 2    C   78.0  100.0     rajkot
# 3    D  100.0    6.0  ahmedabad
# 4    E   90.0    5.0        100

# %% [markdown]
# ### `how()` parameter
# - how = "any"
#     - Removes rows with at least one missing value
# - how = "all"
#     - Removes rows with all missing values

# %%
df.loc[5] = [None,None,None,None]
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C   78.0    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None

# %%
df.dropna(how="any")
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad

# %%
df.dropna(how="all")
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
# 1    B    NaN    7.0      surat
# 2    C   78.0    NaN     rajkot
# 3    D    NaN    6.0  ahmedabad
# 4    E   90.0    5.0       None

# %% [markdown]
# ### `thresh = `
# - Minimum number of non null values to keep in a row

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C   78.0    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None

# %%
df.dropna(thresh=3)
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
# 1    B    NaN    7.0      surat
# 2    C   78.0    NaN     rajkot
# 3    D    NaN    6.0  ahmedabad
# 4    E   90.0    5.0       None

# %%
df.loc[2,"Marks"] = np.nan

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None

# %%
df.dropna(thresh=3)
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
# 1    B    NaN    7.0      surat
# 3    D    NaN    6.0  ahmedabad
# 4    E   90.0    5.0       None

# %% [markdown]
# ### `subset = []` parameter
# - Checks missing values only in specific columns

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None

# %%
df.dropna(subset=["City","Bonus"])
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
# 1    B    NaN    7.0      surat
# 3    D    NaN    6.0  ahmedabad

# %% [markdown]
# ## Drop rows or columns
#
# **syntax**
# ```python
# df.drop(columns = ,index = )
# ```

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None

# %% [markdown]
# ### Remove specific column

# %%
df.drop(columns=["Bonus","City"])
# Out:
#    Name  Marks
# 0     A   85.0
# 1     B    NaN
# 2     C    NaN
# 3     D    NaN
# 4     E   90.0
# 5  None    NaN

# %% [markdown]
# ### Remove specific row

# %%
df.drop(index=2)
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None

# %% [markdown]
# ### Duplicate handling

# %%
df.loc[6] = df.loc[0]

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None
# 6     A   85.0    5.0  ahmedabad

# %% [markdown]
# ### `df.duplicated()`
# - Check the duplicate records

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %% [markdown]
# ### `drop_duplicates()`
# - It removes the duplicate values

# %%
df.drop_duplicates()
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None

# %% [markdown]
# ## SORTING

# %% [markdown]
# ### `sort_values()`
# - Parameters
#     * by = column name
#     * axis = 0 rows/ 1 columns
#     * ascending = True/False
#     * inplace = True/False

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None
# 6     A   85.0    5.0  ahmedabad

# %%
df.sort_values(by="Marks",ascending=False)
# Out:
#    Name  Marks  Bonus       City
# 4     E   90.0    5.0       None
# 0     A   85.0    5.0  ahmedabad
# 6     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 5  None    NaN    NaN       None

# %% [markdown]
# ### sort_index()

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None
# 6     A   85.0    5.0  ahmedabad

# %%
df.sort_index(ascending=False)
# Out:
#    Name  Marks  Bonus       City
# 6     A   85.0    5.0  ahmedabad
# 5  None    NaN    NaN       None
# 4     E   90.0    5.0       None
# 3     D    NaN    6.0  ahmedabad
# 2     C    NaN    NaN     rajkot
# 1     B    NaN    7.0      surat
# 0     A   85.0    5.0  ahmedabad

# %% [markdown]
# ## STATISTICS

# %% [markdown]
# ### `sum()`

# %%
df.sum(axis=0) # For laptop user (new versions use numeric_only = True)
# Out:
# Marks    260.0
# Bonus     28.0
# dtype: float64

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None
# 6     A   85.0    5.0  ahmedabad

# %% [markdown]
# ### mean,mode,median,count

# %%
print("------Mean-------")
print(df.mean(axis=0))
print(df.mean(axis=1))
print("------Median-------")
print(df.median(axis=0))
print(df.median(axis=1))
print("------Mode-------")
print(df.mode(axis=0))
print(df.mode(axis=1))
print("------Count-------")
print(df.count())
# Out:
# ------Mean-------
# Marks    86.666667
# Bonus     5.600000
# dtype: float64
# 0    45.0
# 1     7.0
# 2     NaN
# 3     6.0
# 4    47.5
# 5     NaN
# 6    45.0
# dtype: float64
# ------Median-------
# Marks    85.0
# Bonus     5.0
# dtype: float64
# 0    45.0
# 1     7.0
# 2     NaN
# 3     6.0
# 4    47.5
# 5     NaN
# 6    45.0
# dtype: float64
# ------Mode-------
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
#            0          1    2    3
# 0          A  ahmedabad   85  5.0
# 1          B      surat    7  NaN
# 2          C     rajkot  NaN  NaN
# 3  ahmedabad          D    6  NaN
# 4          5         90    E  NaN
# 5        NaN        NaN  NaN  NaN
# 6          A  ahmedabad   85  5.0
# ------Count-------
# Name     6
# Marks    3
# Bonus    5
# City     5
# dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py:897: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
# ...

# %% [markdown]
# ### `correlation`

# %%
df.corr()
# Out:
#        Marks  Bonus
# Marks    1.0    NaN
# Bonus    NaN    1.0

# %%
2**1000
# Out:
# 

# %% [markdown]
# ### quantile()

# %%
df.quantile(0.2)
# Out:
# Marks    85.0
# Bonus     5.0
# Name: 0.2, dtype: float64

# %%
df.describe(percentiles=[0.2,0.3]).round(2)
# Out:
#        Marks  Bonus
# count   3.00   5.00
# mean   86.67   5.60
# std     2.89   0.89
# min    85.00   5.00
# 20%    85.00   5.00
# 30%    85.00   5.00
# 50%    85.00   5.00
# max    90.00   7.00

# %% [markdown]
# ## SCATTER MATRIX

# %%
pd.plotting.scatter_matrix(df,alpha=0.5,figsize=(6,6))
# Out:
# array([[<AxesSubplot:xlabel='Marks', ylabel='Marks'>,
#         <AxesSubplot:xlabel='Bonus', ylabel='Marks'>],
#        [<AxesSubplot:xlabel='Marks', ylabel='Bonus'>,
#         <AxesSubplot:xlabel='Bonus', ylabel='Bonus'>]], dtype=object)

# %% [markdown]
# ### Parallel coordinates

# %%
df
# Out:
#    Name  Marks  Bonus       City
# 0     A   85.0    5.0  ahmedabad
# 1     B    NaN    7.0      surat
# 2     C    NaN    NaN     rajkot
# 3     D    NaN    6.0  ahmedabad
# 4     E   90.0    5.0       None
# 5  None    NaN    NaN       None
# 6     A   85.0    5.0  ahmedabad

# %%
df.drop(index=5,inplace=True)
df
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
# 1    B    NaN    7.0      surat
# 2    C    NaN    NaN     rajkot
# 3    D    NaN    6.0  ahmedabad
# 4    E   90.0    5.0       None
# 6    A   85.0    5.0  ahmedabad

# %%
df2 = df[["Marks","Bonus","City"]].fillna(0)

# %%
df2
# Out:
#    Marks  Bonus       City
# 0   85.0    5.0  ahmedabad
# 1    0.0    7.0      surat
# 2    0.0    0.0     rajkot
# 3    0.0    6.0  ahmedabad
# 4   90.0    5.0          0
# 6   85.0    5.0  ahmedabad

# %%
pd.plotting.parallel_coordinates(df2,class_column="City")
plt.show()

# %% [markdown]
# ## CROSSTAB
# - This method is used for multivariate classification

# %%
pd.crosstab(df["City"],df["Name"], margins=True)
# Out:
# Name       A  B  C  D  All
# City
# ahmedabad  2  0  0  1    3
# rajkot     0  0  1  0    1
# surat      0  1  0  0    1
# All        2  1  1  1    5

# %%
df
# Out:
#   Name  Marks  Bonus       City
# 0    A   85.0    5.0  ahmedabad
# 1    B    NaN    7.0      surat
# 2    C    NaN    NaN     rajkot
# 3    D    NaN    6.0  ahmedabad
# 4    E   90.0    5.0       None
# 6    A   85.0    5.0  ahmedabad

# %% [markdown]
# ## Load csv from internet

# %%
df = pd.read_csv("https://raw.githubusercontent.com/patelmanishv/Sem4Data/refs/heads/main/Datasets/auto-mpg.csv")

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
print(df.head())
print(df.tail())
print(df.describe())
print(df.info())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# ...

# %% [markdown]
# ## OUTLIER ANALYSIS
# - Outliers are the extreme values, which can skew the data analysis
# - Removing outliers can normalize the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Name": ['A','B','C','D','E','F','G','H','I','J'],
    "Marks": [85,72,90,80,88,91,95,87,300,5],
    "Age":[21,19,23,20,22,21,24,23,20,18],
    "City":['ahmedabad','delhi','delhi','mumbai','surat','mumbai','delhi','mumbai',"surat","ahmedabad"]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks  Age       City
# 0    A     85   21  ahmedabad
# 1    B     72   19      delhi
# 2    C     90   23      delhi
# 3    D     80   20     mumbai
# 4    E     88   22      surat
# 5    F     91   21     mumbai
# 6    G     95   24      delhi
# 7    H     87   23     mumbai
# 8    I    300   20      surat
# 9    J      5   18  ahmedabad

# %% [markdown]
# ## VISUALIZE THE OUTLIERS

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df["Marks"])
plt.title("Boxplot of Marks")
plt.show()

# %% [markdown]
# ### Filtering the data

# %%
print(df)
# Out:
#   Name  Marks  Age       City
# 0    A     85   21  ahmedabad
# 1    B     72   19      delhi
# 2    C     90   23      delhi
# 3    D     80   20     mumbai
# 4    E     88   22      surat
# 5    F     91   21     mumbai
# 6    G     95   24      delhi
# 7    H     87   23     mumbai
# 8    I    300   20      surat
# 9    J      5   18  ahmedabad

# %%
df["Marks"] > 80
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9    False
# Name: Marks, dtype: bool

# %% [markdown]
# ## extract the column

# %%
df[df["Marks"] > 80]
# Out:
#   Name  Marks  Age       City
# 0    A     85   21  ahmedabad
# 2    C     90   23      delhi
# 4    E     88   22      surat
# 5    F     91   21     mumbai
# 6    G     95   24      delhi
# 7    H     87   23     mumbai
# 8    I    300   20      surat

# %% [markdown]
# ## Student with age > 21 and marks > 85

# %%
(df["Age"] > 21) & (df["Marks"] > 85)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9    False
# dtype: bool

# %%
df[(df["Age"] > 21) & (df["Marks"] > 85)]
# Out:
#   Name  Marks  Age    City
# 2    C     90   23   delhi
# 4    E     88   22   surat
# 6    G     95   24   delhi
# 7    H     87   23  mumbai

# %% [markdown]
# ## filtering using `or` -> |

# %% [markdown]
# ###  students from surat or delhi

# %%
(df["City"] == "delhi") | (df["City"] == "surat")
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# Name: City, dtype: bool

# %%
df[(df["City"] == "delhi") | (df["City"] == "surat")]
# Out:
#   Name  Marks  Age   City
# 1    B     72   19  delhi
# 2    C     90   23  delhi
# 4    E     88   22  surat
# 6    G     95   24  delhi
# 8    I    300   20  surat

# %% [markdown]
# ## FUNCTION TO DETECT OUTLIER
# - REFERENCE PB Q-58 (MOST IMP)
# ![1_0MPDTLn8KoLApoFvI0P2vQ.png](attachment:1_0MPDTLn8KoLApoFvI0P2vQ.png)

# %%
def detectoutlier(df,column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
        
    outliers = df[(df[column]<lower) | (df[column]>upper)]
    
    return outliers

# %%
detectoutlier(df,"Marks")
# Out:
#   Name  Marks  Age       City
# 8    I    300   20      surat
# 9    J      5   18  ahmedabad

# %% [markdown]
# ### FUNCTION TO REMOVE OUTLIERS

# %%
def removeoutlier(df,column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
        
    cleandf = df[(df[column]>=lower) & (df[column]<=upper)]
    
    return cleandf

# %%
removeoutlier(df,"Marks")
# Out:
#   Name  Marks  Age       City
# 0    A     85   21  ahmedabad
# 1    B     72   19      delhi
# 2    C     90   23      delhi
# 3    D     80   20     mumbai
# 4    E     88   22      surat
# 5    F     91   21     mumbai
# 6    G     95   24      delhi
# 7    H     87   23     mumbai

# %% [markdown]
# ## PANDAS TRANSFORMATION

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "ID":[1,2,3,4],
    "Name":['A','B','C','D'],
    "Department":['IT','HR','IT','HR'],
    "Salary":[50000,60000,55000,52000],
    "Bonus":[5000,7000,4000,3500]
    },index = [2,3,0,1])
df
# Out:
#    ID Name Department  Salary  Bonus
# 2   1    A         IT   50000   5000
# 3   2    B         HR   60000   7000
# 0   3    C         IT   55000   4000
# 1   4    D         HR   52000   3500

# %%
df2 = pd.DataFrame({
    "ID":[2,3,5],
    "Salary":[61000,57000,62000],
    "City":['ahmedabad','surat','vadodara']
})
df2
# Out:
#    ID  Salary       City
# 0   2   61000  ahmedabad
# 1   3   57000      surat
# 2   5   62000   vadodara

# %% [markdown]
# ### apply()
# - This method is used to apply functions to the dataframe

# %%
df,df2
# Out:
# (   ID Name Department  Salary  Bonus
#  2   1    A         IT   50000   5000
#  3   2    B         HR   60000   7000
#  0   3    C         IT   55000   4000
#  1   4    D         HR   52000   3500,
#     ID  Salary       City
#  0   2   61000  ahmedabad
#  1   3   57000      surat
#  2   5   62000   vadodara)

# %%
df.apply(lambda x:x.sum() if x.dtype != 'object' else x,axis=0)
# Out:
# ID                                                           10
# Name          2    A
# 3    B
# 0    C
# 1    D
# Name: Name, dtype:...
# Department    2    IT
# 3    HR
# 0    IT
# 1    HR
# Name: Departme...
# Salary                                                   217000
# Bonus                                                     19500
# dtype: object

# %%
df,df2
# Out:
# (   ID Name Department  Salary  Bonus
#  2   1    A         IT   50000   5000
#  3   2    B         HR   60000   7000
#  0   3    C         IT   55000   4000
#  1   4    D         HR   52000   3500,
#     ID  Salary       City
#  0   2   61000  ahmedabad
#  1   3   57000      surat
#  2   5   62000   vadodara)

# %%
df.apply(lambda row: row["Salary"] + row["Bonus"],axis=1)
# Out:
# 2    55000
# 3    67000
# 0    59000
# 1    55500
# dtype: int64

# %% [markdown]
# ### raw = True / False
# - raw = False means the data input is Series
# - raw = True means the datainput is numpy

# %%
df[["Salary","Bonus"]].apply(lambda row:row["Salary"] + row["Bonus"],axis=1,
                            raw = False)
# Out:
# 2    55000
# 3    67000
# 0    59000
# 1    55500
# dtype: int64

# %%
df[["Salary","Bonus"]].apply(lambda row:row[0] + row[1],axis=1,raw=True)
# Out:
# 2    55000
# 3    67000
# 0    59000
# 1    55500
# dtype: int64

# %% [markdown]
# ## result_type = 'expand'

# %%
df
# Out:
#    ID Name Department  Salary  Bonus
# 2   1    A         IT   50000   5000
# 3   2    B         HR   60000   7000
# 0   3    C         IT   55000   4000
# 1   4    D         HR   52000   3500

# %%
df[["Salary","Bonus"]].apply(lambda row:[row["Salary"] + row["Bonus"],
                                         row["Salary"] - row["Bonus"]],
                             axis=1, result_type = 'expand')
# Out:
#        0      1
# 2  55000  45000
# 3  67000  53000
# 0  59000  51000
# 1  55500  48500

# %% [markdown]
# ## args

# %%
df["Salary"].apply(lambda x,add:x + add,args=(1000,))
# Out:
# 2    51000
# 3    61000
# 0    56000
# 1    53000
# Name: Salary, dtype: int64

# %% [markdown]
# ## astype()
# - It typecast the given column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 2 to 1
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          4 non-null      int64
#  1   Name        4 non-null      object
#  2   Department  4 non-null      object
#  3   Salary      4 non-null      int64
#  4   Bonus       4 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 192.0+ bytes

# %%
df["Salary"] = df["Salary"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 2 to 1
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          4 non-null      int64
#  1   Name        4 non-null      object
#  2   Department  4 non-null      object
#  3   Salary      4 non-null      float64
#  4   Bonus       4 non-null      int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 192.0+ bytes

# %% [markdown]
# ## replace(oldvalue,newvalue,inplace = True/False)
# - This method is used to replace old value with new value

# %%
df
# Out:
#    ID Name Department   Salary  Bonus
# 2   1    A         IT  50000.0   5000
# 3   2    B         HR  60000.0   7000
# 0   3    C         IT  55000.0   4000
# 1   4    D         HR  52000.0   3500

# %%
df["Salary"].replace(50000.0,53000,inplace=True)
# Out:
# C:\Users\LJENG\AppData\Local\Temp\ipykernel_1684\282408595.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Salary"].replace(50000.0,53000,inplace=True)

# %%
df
# Out:
#    ID Name Department   Salary  Bonus
# 2   1    A         IT  53000.0   5000
# 3   2    B         HR  60000.0   7000
# 0   3    C         IT  55000.0   4000
# 1   4    D         HR  52000.0   3500

# %% [markdown]
# ## CONCAT
# - This method is used to stack two dataframes axis wise

# %%
pd.concat([df,df],axis=1)
# Out:
#    ID Name Department   Salary  Bonus  ID Name Department   Salary  Bonus
# 2   1    A         IT  53000.0   5000   1    A         IT  53000.0   5000
# 3   2    B         HR  60000.0   7000   2    B         HR  60000.0   7000
# 0   3    C         IT  55000.0   4000   3    C         IT  55000.0   4000
# 1   4    D         HR  52000.0   3500   4    D         HR  52000.0   3500

# %%
pd.concat([df,df],axis=0,sort=True,ignore_index=True)
# Out:
#    Bonus Department  ID Name   Salary
# 0   5000         IT   1    A  53000.0
# 1   7000         HR   2    B  60000.0
# 2   4000         IT   3    C  55000.0
# 3   3500         HR   4    D  52000.0
# 4   5000         IT   1    A  53000.0
# 5   7000         HR   2    B  60000.0
# 6   4000         IT   3    C  55000.0
# 7   3500         HR   4    D  52000.0

# %% [markdown]
# ## join parameter
# - join = 'outer' means keep union of indexes/columns
# - join = 'inner' means keep only common indexes

# %%
df,df2
# Out:
# (   ID Name Department   Salary  Bonus
#  2   1    A         IT  53000.0   5000
#  3   2    B         HR  60000.0   7000
#  0   3    C         IT  55000.0   4000
#  1   4    D         HR  52000.0   3500,
#     ID  Salary       City
#  0   2   61000  ahmedabad
#  1   3   57000      surat
#  2   5   62000   vadodara)

# %%
pd.concat([df,df2],join="outer")
# Out:
#    ID Name Department   Salary   Bonus       City
# 2   1    A         IT  53000.0  5000.0        NaN
# 3   2    B         HR  60000.0  7000.0        NaN
# 0   3    C         IT  55000.0  4000.0        NaN
# 1   4    D         HR  52000.0  3500.0        NaN
# 0   2  NaN        NaN  61000.0     NaN  ahmedabad
# 1   3  NaN        NaN  57000.0     NaN      surat
# 2   5  NaN        NaN  62000.0     NaN   vadodara

# %%
df,df2
# Out:
# (   ID Name Department   Salary  Bonus
#  2   1    A         IT  53000.0   5000
#  3   2    B         HR  60000.0   7000
#  0   3    C         IT  55000.0   4000
#  1   4    D         HR  52000.0   3500,
#     ID  Salary       City
#  0   2   61000  ahmedabad
#  1   3   57000      surat
#  2   5   62000   vadodara)

# %%
pd.concat([df,df2],axis = 1,join="inner",sort=True)
# Out:
#    ID Name Department   Salary  Bonus  ID  Salary       City
# 0   3    C         IT  55000.0   4000   2   61000  ahmedabad
# 1   4    D         HR  52000.0   3500   3   57000      surat
# 2   1    A         IT  53000.0   5000   5   62000   vadodara

# %% [markdown]
# # MERGE
# - Merge joins two dataframes based on common keys/columns
# - SQL type operation

# %%
df,df2
# Out:
# (   ID Name Department   Salary  Bonus
#  2   1    A         IT  53000.0   5000
#  3   2    B         HR  60000.0   7000
#  0   3    C         IT  55000.0   4000
#  1   4    D         HR  52000.0   3500,
#     ID  Salary       City
#  0   2   61000  ahmedabad
#  1   3   57000      surat
#  2   5   62000   vadodara)

# %%
pd.merge(df,df2,how = 'inner',on="ID") # Common IDs
# Out:
#    ID Name Department  Salary_x  Bonus  Salary_y       City
# 0   2    B         HR   60000.0   7000     61000  ahmedabad
# 1   3    C         IT   55000.0   4000     57000      surat

# %%
pd.merge(df,df2,how = 'left',on="ID") # Common IDs
# Out:
#    ID Name Department  Salary_x  Bonus  Salary_y       City
# 0   1    A         IT   53000.0   5000       NaN        NaN
# 1   2    B         HR   60000.0   7000   61000.0  ahmedabad
# 2   3    C         IT   55000.0   4000   57000.0      surat
# 3   4    D         HR   52000.0   3500       NaN        NaN

# %%
pd.merge(df,df2,how = 'right',on="ID") # Common IDs
# Out:
#    ID Name Department  Salary_x   Bonus  Salary_y       City
# 0   2    B         HR   60000.0  7000.0     61000  ahmedabad
# 1   3    C         IT   55000.0  4000.0     57000      surat
# 2   5  NaN        NaN       NaN     NaN     62000   vadodara

# %% [markdown]
# ### left_on and right_on
# - It merges based on left and right column names given

# %%
pd.merge(df,df2,left_on="ID", right_on="StudentID")
# Out:
#    ID Name Department  Salary_x  Bonus  StudentID  Salary_y       City
# 0   2    B         HR   60000.0   7000          2     61000  ahmedabad
# 1   3    C         IT   55000.0   4000          3     57000      surat

# %%
df2 = pd.DataFrame({
    "ID":[2,3,5],
    "Salary":[61000,57000,62000],
    "City":['ahmedabad','surat','vadodara']
})
df2
# Out:
#    ID  Salary       City
# 0   2   61000  ahmedabad
# 1   3   57000      surat
# 2   5   62000   vadodara

# %% [markdown]
# ### left_index and right_index
# - It merges based on left and right index

# %%
pd.merge(df.set_index("ID"),df2.set_index("ID"),left_index=True,right_index=True)
# Out:
#    Name Department  Salary_x  Bonus  Salary_y       City
# ID
# 2     B         HR   60000.0   7000     61000  ahmedabad
# 3     C         IT   55000.0   4000     57000      surat

# %% [markdown]
# ### suffixes = ()

# %%
pd.merge(df.set_index("ID"),df2.set_index("ID"),
         left_index=True,right_index=True,suffixes=("_emp","_city"))
# Out:
#    Name Department  Salary_emp  Bonus  Salary_city       City
# ID
# 2     B         HR     60000.0   7000        61000  ahmedabad
# 3     C         IT     55000.0   4000        57000      surat

# %% [markdown]
# # GROUPBY
# - It provides groupwise computation using custom / inbuilt function

# %%
g = df.groupby(by="Department", as_index=True,sort=True)

# %%
df
# Out:
#    ID Name Department   Salary  Bonus
# 2   1    A         IT  53000.0   5000
# 3   2    B         HR  60000.0   7000
# 0   3    C         IT  55000.0   4000
# 1   4    D         HR  52000.0   3500

# %%
g.groups # dictionary of column names as keys and indexes as values
# Out:
# {'HR': [3, 1], 'IT': [2, 0]}

# %%
print(g["Salary"].sum()) # groupwise sum of salaries
print(g["Bonus"].sum()) # groupwise sum of bonuses
print(g["Bonus"].mean()) # groupwise mean of bonuses
print(g["Bonus"].median()) # groupwise median of bonuses
# Out:
# Department
# HR    112000.0
# IT    108000.0
# Name: Salary, dtype: float64
# Department
# HR    10500
# IT     9000
# Name: Bonus, dtype: int64
# Department
# HR    5250.0
# IT    4500.0
# Name: Bonus, dtype: float64
# Department
# HR    5250.0
# IT    4500.0
# Name: Bonus, dtype: float64

# %% [markdown]
# ### agg method
# - It aggregates required functions into one dataframe

# %%
g["Salary"].agg(["min","max","sum","median","mean"])
# Out:
#                 min      max       sum   median     mean
# Department
# HR          52000.0  60000.0  112000.0  56000.0  56000.0
# IT          53000.0  55000.0  108000.0  54000.0  54000.0

# %% [markdown]
# ### using with apply method

# %%
g["Salary"].apply(lambda x: x.max() - x.min())
# Out:
# Department
# HR    8000.0
# IT    2000.0
# Name: Salary, dtype: float64

# %%
g.sample(1) # random sample from each group
# Out:
#    ID Name Department   Salary  Bonus
# 3   2    B         HR  60000.0   7000
# 0   3    C         IT  55000.0   4000

# %%
g.size() # number of rows per group
# Out:
# Department
# HR    2
# IT    2
# dtype: int64

# %%
g.nth(0) # select first record from each group
# Out:
#    ID Name Department   Salary  Bonus
# 2   1    A         IT  53000.0   5000
# 3   2    B         HR  60000.0   7000

# %%
print(g["Salary"].unique()) # unique data in the column
print(g["Salary"].nunique()) # number of unique data in the column
print(g["Salary"].count()) # number of non null values
# Out:
# Department
# HR    [60000.0, 52000.0]
# IT    [53000.0, 55000.0]
# Name: Salary, dtype: object
# Department
# HR    2
# IT    2
# Name: Salary, dtype: int64
# Department
# HR    2
# IT    2
# Name: Salary, dtype: int64
