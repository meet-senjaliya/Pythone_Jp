# %% [markdown]
# <a href="https://colab.research.google.com/github/meet-senjaliya/Pythone_Jp/blob/main/MNIST%20DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hii')
# Out:
# hii
